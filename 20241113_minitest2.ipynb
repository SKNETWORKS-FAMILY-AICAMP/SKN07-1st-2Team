# %%
# !pip install openpyxl
# 필요 import 한번에 
from bs4 import BeautifulSoup as BS
from tqdm import tqdm 
import numpy as np
import os
import pandas as pd
import requests
import pickle
import time

# %%
# 엑셀 파일을 읽어옵니다.
directory_path = "../../../Downloads"  # 다운로드 폴더에 있을경우
# 엑셀 파일들의 이름 리스트 ('_통계' 문구 있는것만)
excel_files = [f for f in os.listdir(directory_path) if f.endswith('_통계.xlsx')]

# 각 파일의 시트를 저장할 딕셔너리
all_data = {}

for file_name in excel_files:
    file_path = os.path.join(directory_path, file_name)
    # 파일에서 모든 시트를 읽어옴
    sheets = pd.read_excel(file_path, sheet_name=None)
    
    # 각 파일의 시트들을 딕셔너리에 저장
    all_data[file_name] = sheets

# 결과 확인 (파일과 시트 이름을 출력)
for file, sheets in all_data.items():
    print(f"File: {file}")
    for sheet_name, df in sheets.items():
        print(f"  Sheet name: {sheet_name}")
        print(df.head())  # 시트 데이터의 첫 몇 줄을 출력
# Out:
# File: 2023년_10월_자동차_등록자료_통계.xlsx
#   Sheet name: 01.통계표
#   Unnamed: 0 Unnamed: 1 Unnamed: 2        <     자동차      통계표 Unnamed: 6  \
# 0      조회년월:    2023.10        NaN      NaN     NaN      NaN        NaN
# 1         차종         차종         승용      NaN     NaN      NaN         승합
# 2        용도별        NaN         관용      자가용     영업용        계         관용
# 3        시도별        NaN        NaN      NaN     NaN      NaN        NaN
# 4         서울        NaN       4592  2649600  120923  2775115       3710
#
#        > Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0    NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1    NaN        NaN        NaN  ...         NaN         NaN          특수
# 2    자가용        영업용          계  ...         영업용           계          관용
# 3    NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4  73036      14996      91742  ...       60266      313655         415
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN          총계         NaN         NaN
# 2         자가용         영업용           계          관용         자가용         영업용
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4        5673        5232       11320       12661     2977754      201417
#
#   Unnamed: 21
# 0         NaN
# 1         NaN
# 2           계
# 3         NaN
# 4     3191832
#
# [5 rows x 22 columns]
#   Sheet name: 02.통계표_시군구
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3      <     자동차      통계표  \
# 0      조회년월:    2023.10        NaN        NaN    NaN     NaN      NaN
# 1         시도        시군구   승      용        NaN    NaN     NaN  승     합
# 2        NaN        NaN         관용        자가용    영업용       계       관용
# 3         서울        강남구        159     212274  18962  231395       56
# 4        NaN        강동구        113     128922   5059  134094       41
#
#   Unnamed: 7    > Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0        NaN  NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN  NaN        NaN  ...         NaN         NaN     특     수
# 2        자가용  영업용          계  ...         영업용           계          관용
# 3       4030  550       4636  ...        2397       16241          18
# 4       3399  794       4234  ...        2507       14848           6
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN     총     계         NaN         NaN
# 2         자가용         영업용           계          관용         자가용         영업용
# 3         341         161         520         412      230310       22070
# 4         209         221         436         314      144717        8581
#
#   Unnamed: 21
# 0         NaN
# 1         NaN
# 2           계
# 3      252792
# 4      153612
#
# [5 rows x 22 columns]
#   Sheet name: 03.수입차_시군구
#   Unnamed: 0 Unnamed: 1       <  시군구  수입차    > Unnamed: 6
# 0      조회년월:    2023.10     NaN  NaN  NaN  NaN        NaN
# 1         시도        시군구      승용   승합   화물   특수         합계
# 2        NaN        NaN     NaN  NaN  NaN  NaN        NaN
# 3         서울        강남구  100156  276  476  122     101030
# 4        NaN        강동구   26175   93  265   53      26586
#   Sheet name: 04.성별_연령별
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       <     자동차      성별     연령별  자동차.1  \
# 0      조회년월:    2023.10        NaN     NaN     NaN     NaN     NaN    NaN
# 1         성별      연령/시도         총계      서울      부산      대구      인천     광주
# 2         남성      10대이하       9740    2306     565     214     482    159
# 3        NaN        20대     541573   53299   26826   24516   32885  19147
# 4        NaN        30대    2333359  318679  126161  110260  145464  67644
#
#      통계표      > Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0    NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 1     대전     울산          세종          경기          강원          충북          충남
# 2    293    210          79        2620         241         380         344
# 3  18712  13880        3549      150739       21458       24958       31412
# 4  71414  56714       25018      694768       69075       84631      119170
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0         NaN         NaN         NaN         NaN         NaN
# 1          전북          전남          경북          경남          제주
# 2         354         326         288         662         217
# 3       21320       23658       31713       36075        7426
# 4       71084       75570      117289      150730       29688
#   Sheet name: 05.차종별_등록현황(전체)
#   < 자동차 등록현황(총 계) > Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     조회년월: 2023.10        NaN        NaN        NaN        NaN        NaN
# 1               NaN        NaN        NaN        NaN      차 종 별         서울
# 2                총계        NaN        NaN        NaN        NaN    3191832
# 3               NaN      승용차합계        NaN        NaN        NaN    2775115
# 4               NaN        NaN    승용일반형 계        NaN        NaN    1842913
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         부산         대구         인천         광주  ...          경기          강원
# 2    1523018    1254866    1726733     721215  ...     6496646      864864
# 3    1287133    1060353    1476304     606494  ...     5425805      667494
# 4     835567     717765     919484     398816  ...     3436781      410497
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          충북          충남          전북          전남          경북          경남
# 2      933878     1240350      990336     1243731     1530862     1935481
# 3      734063      960225      760818      941672     1152813     1577326
# 4      467380      609844      483248      575493      764199     1031589
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1          제주          합계
# 2      701839    25870152
# 3      593153    21312794
# 4      341599    13680463
#
# [5 rows x 23 columns]
#   Sheet name: 06.차종별_등록현황(관용)
#   < 자동차 등록현황(관 용) > Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     조회년월: 2023.10        NaN        NaN        NaN        NaN        NaN
# 1               NaN        NaN        NaN        NaN      차 종 별         서울
# 2                총계        NaN        NaN        NaN        NaN      12661
# 3               NaN      승용차합계        NaN        NaN        NaN       4592
# 4               NaN        NaN    승용일반형 계        NaN        NaN       3186
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         부산         대구         인천         광주  ...          경기          강원
# 2       4817       3692       4322       2410  ...       18641        6596
# 3       1741       1056       1644        874  ...        7889        1950
# 4       1186        694       1168        575  ...        5016        1056
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          충북          충남          전북          전남          경북          경남
# 2        4338        6121        5680        6985        7867        7547
# 3        1410        2014        1887        2355        2690        2567
# 4         893        1235        1114        1398        1557        1486
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1          제주          합계
# 2        2460       99194
# 3         848       35269
# 4         629       22288
#
# [5 rows x 23 columns]
#   Sheet name: 07.차종별_등록현황(자가용)
#   < 자동차 등록현황(자 가 용) > Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       조회년월: 2023.10        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN      차 종 별         서울
# 2                  총계        NaN        NaN        NaN        NaN    2977754
# 3                 NaN      승용차합계        NaN        NaN        NaN    2649600
# 4                 NaN        NaN    승용일반형 계        NaN        NaN    1753691
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         부산         대구         인천         광주  ...          경기          강원
# 2    1344931    1195619    1440315     686064  ...     6222565      831715
# 3    1163388    1030380    1240068     591658  ...     5341003      653083
# 4     774592     695812     779926     386883  ...     3375325      400572
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          충북          충남          전북          전남          경북          경남
# 2      889477     1192774      948154     1006756     1473950     1776820
# 3      715191      944714      745113      743844     1136615     1463802
# 4      454433      598395      472077      466826      751670      975414
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1          제주          합계
# 2      419515    23852081
# 3      323839    20004226
# 4      200393    12909295
#
# [5 rows x 23 columns]
#   Sheet name: 08.차종별 등록현황(영업용)
#   < 자동차 등록현황(영 업 용) > Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       조회년월: 2023.10        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN      차 종 별         서울
# 2                  총계        NaN        NaN        NaN        NaN     201417
# 3                 NaN      승용차합계        NaN        NaN        NaN     120923
# 4                 NaN        NaN    승용일반형 계        NaN        NaN      86036
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         부산         대구         인천         광주  ...          경기          강원
# 2     173270      55555     282096      32741  ...      255440       26553
# 3     122004      28917     234592      13962  ...       76913       12461
# 4      59789      21259     138390      11358  ...       56440        8869
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          충북          충남          전북          전남          경북          경남
# 2       40063       41455       36502      229990       49045      151114
# 3       17462       13497       13818      195473       13508      110957
# 4       12054       10214       10057      107269       10972       54689
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1          제주          합계
# 2      279864     1918877
# 3      268466     1273299
# 4      140577      748880
#
# [5 rows x 23 columns]
#   Sheet name: 09.차종별_유형별 현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       <     차종별     유형별    등록현황 Unnamed: 7  \
# 0      조회년월:    2023.10        NaN     NaN     NaN     NaN     NaN        NaN
# 1        NaN        시도별         서울      부산      대구      인천      광주         대전
# 2         종별        유형별        NaN     NaN     NaN     NaN     NaN        NaN
# 3         승용         일반    1842913  835567  717765  919484  398816     407424
# 4        NaN      승용겸화물      11825    4375    3456   12648    2222       2462
#
#         > Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0     NaN        NaN         NaN         NaN         NaN         NaN
# 1      울산         세종          경기          강원          충북          충남
# 2     NaN        NaN         NaN         NaN         NaN         NaN
# 3  323011     114853     3436781      410497      467380      609844
# 4    1437        493       21068        2848        3060        3725
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          전북          전남          경북          경남          제주           계
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3      483248      575493      764199     1031589      341599    13680463
# 4        2438        8377        3681        5759        7229       97103
#   Sheet name: 10.연료별_등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    <  연료별  차종별  용도별 등록현황 Unnamed: 8    >  \
# 0      조회년월:    2023.10        NaN  NaN  NaN  NaN  NaN  NaN        NaN  NaN
# 1        연료별        시도별        NaN   서울   부산   대구   인천   광주         대전   울산
# 2        NaN         종별        용도별  NaN  NaN  NaN  NaN  NaN        NaN  NaN
# 3        휘발유                   NaN  NaN  NaN  NaN  NaN  NaN        NaN  NaN
# 4        휘발유                   NaN  NaN  NaN  NaN  NaN  NaN        NaN  NaN
#
#    ... Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0  ...         NaN         NaN         NaN         NaN         NaN
# 1  ...          경기          강원          충북          충남          전북
# 2  ...         NaN         NaN         NaN         NaN         NaN
# 3  ...         NaN         NaN         NaN         NaN         NaN
# 4  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0         NaN         NaN         NaN         NaN         NaN
# 1          전남          경북          경남          제주           계
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 21 columns]
#   Sheet name: 11.최대적재량별_등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       < 최대적재량별  화물자동차   등록현황 Unnamed: 7  \
# 0      조회년월:    2023.10        NaN     NaN    NaN    NaN    NaN        NaN
# 1          규        NaN          모   1톤 이하  1톤 초과  3톤 이상  5톤 이상      8톤 이상
# 2         시도       유  형       용  도     NaN  3톤 미만  5톤 미만  8톤 미만     10톤 미만
# 3         서울        일반형       비사업용  143617  11816   5194   2046        344
# 4        NaN        NaN        사업용   19184   3542   6483   2387       1150
#
#         > Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0     NaN        NaN         NaN         NaN         NaN
# 1  10톤 이상     12톤 이상      15톤 이상      20톤 이상           계
# 2  12톤 미만     15톤 미만      20톤 미만         NaN         NaN
# 3     286        158         190         161      163812
# 4     382        909         237        1369       35643
#   Sheet name: 12.배기별(승용차)_등록현황
#   Unnamed: 0        <     승용차의     배기량별     등록현황 Unnamed: 5        >  \
# 0      조회년월:  2023.10      NaN      NaN      NaN        NaN      NaN
# 1        NaN      배기량  1000 미만  1000 이상  1600 이상    2000 이상  2500 이상
# 2         시도      NaN      NaN  1600 미만  2000 미만    2500 미만      NaN
# 3         서울      NaN   179416   560554  1016561     449014   507524
# 4         부산      NaN   104508   272515   458125     208366   216057
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN
# 1      저속전기차        전기차          계
# 2        NaN        NaN        NaN
# 3         46      62000    2775115
# 4         18      27544    1287133
#   Sheet name: 13.차종별_등록(시도)
#   Unnamed: 0        <      차종별    용도별    등록현황 Unnamed: 5        >
# 0      조회년월:  2023.10      NaN    NaN     NaN        NaN      NaN
# 1        NaN      차종별       승용     승합      화물         특수        계
# 2         시도       용도      NaN    NaN     NaN        NaN      NaN
# 3         서울      사업용   120923  14996   60266       5232   201417
# 4        NaN     비사업용  2654192  76746  253389       6088  2990415
#   Sheet name: 14.차종별_상세등록(시도)
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    <     차령별  차종별    용도별 등록현황  \
# 0        NaN      조회년월:    2023.10        NaN  NaN     NaN  NaN    NaN  NaN
# 1         시도         차종        승 용        NaN  NaN     NaN  승 합    NaN  NaN
# 2        NaN       모델연도         관용        자가용  영업용       계   관용    자가용  영업용
# 3         서울       2003         35     124255  117  124407    7  13108  114
# 4        NaN       2004         12      21059    3   21074    0    422    1
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         특 수         NaN         NaN
# 2          계  ...         영업용           계          관용         자가용         영업용
# 3      13229  ...        1825       39686           0         429         101
# 4        423  ...         482        2826           2          22          23
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         합 계         NaN         NaN         NaN
# 2           계          관용         자가용         영업용           계
# 3         530          52      175643        2157      177852
# 4          47          42       23819         509       24370
#
# [5 rows x 22 columns]
#   Sheet name: 15.차령별_차종별_용도별 등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    <     차령별  차종별    용도별 등록현황   (총계)    >  \
# 0      조회년월:    2023.10        NaN  NaN     NaN  NaN    NaN  NaN    NaN  NaN
# 1         차종        승 용        NaN  NaN     NaN  승 합    NaN  NaN    NaN  화 물
# 2       모델년도         관용        자가용  영업용       계   관용    자가용  영업용      계   관용
# 3       2003         96     632292  427  632815   15  70829  532  71376   93
# 4       2004         29     114872   11  114912    3   3439   20   3462   68
#
#    ... Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0  ...         NaN         NaN         NaN         NaN         NaN
# 1  ...         NaN         NaN         특 수         NaN         NaN
# 2  ...         영업용           계          관용         자가용         영업용
# 3  ...       27824      373904          10        4297        2845
# 4  ...        5049       45499           2         478         775
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         합 계         NaN         NaN         NaN
# 2           계          관용         자가용         영업용           계
# 3        7152         214     1053405       31628     1085247
# 4        1255         102      159171        5855      165128
#
# [5 rows x 21 columns]
#   Sheet name: 16.승차정원별(승합차) 등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2     <  승합차의   승차정원별    등록현황 Unnamed: 7  \
# 0      조회년월:    2023.10        NaN   NaN   NaN     NaN     NaN        NaN
# 1          규          모       0-3명  4-6명  7-9명  10-12명  13-15명     16-25명
# 2         시도         용도        NaN   NaN   NaN     NaN     NaN        NaN
# 3         서울        사업용        164    35     4    2445     467       2023
# 4        NaN       비사업용       2211  6619  8247   50319    4674       1644
#
#         > Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0     NaN        NaN         NaN         NaN         NaN
# 1  26-35명     36-45명      46-50명      50명 이상           계
# 2     NaN        NaN         NaN         NaN         NaN
# 3    1016        773        5421        2648       14996
# 4    1113        747        1116          56       76746
#   Sheet name: 17.차종별_규모별 등록현황_초소형
#   Unnamed: 0        <      차종별    규모별    등록현황 Unnamed: 5        >
# 0      조회년월:  2023.10      NaN    NaN     NaN        NaN      NaN
# 1        NaN      차종별       승용     승합      화물         특수        계
# 2         시도       규모      NaN    NaN     NaN        NaN      NaN
# 3         서울       소형    39342   4542  238812       7276   289972
# 4        NaN       중형  1599667  68655   38864       2015  1709201
#   Sheet name: 18.자가용 자동차 증가추세
#   Unnamed: 0        <    자가용     자동차      증가추세         > Unnamed: 6  \
# 0      조회년월:  2023.10    NaN     NaN       NaN       NaN        NaN
# 1         구분      NaN  총보유대수  자가용총대수  자가용승용차전국  자가용승용차서울      자가용승합
# 2         년도        계    NaN     NaN       NaN       NaN        NaN
# 3        NaN   증가율(%)    NaN     NaN       NaN       NaN        NaN
# 4        NaN   구성비(%)    NaN     NaN       NaN       NaN        NaN
#
#   Unnamed: 7 Unnamed: 8
# 0        NaN        NaN
# 1      자가용화물      자가용특수
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
#   Sheet name: 19.연도별 자동차 등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       <       년도별    자동차    등록현황  \
# 0      조회년월:    2023.10        NaN     NaN       NaN    NaN     NaN
# 1         차종         승용        NaN     NaN       NaN     승합     NaN
# 2         년도         관용        자가용     영업용         계     관용     자가용
# 3       2007      20714   11674085  404980  12099779  12650  999807
# 4       2008      21388   12025715  436706  12483809  13269  987448
#
#   Unnamed: 7        > Unnamed: 9  ... Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0        NaN      NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN      NaN         화물  ...         NaN         NaN          특수
# 2        영업용        계         관용  ...         영업용           계          관용
# 3      92492  1104949      25230  ...      334584     3171351        2090
# 4      95981  1096698      25535  ...      338711     3160338        2110
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN          합계         NaN         NaN
# 2         자가용         영업용           계          관용         자가용         영업용
# 3       10945       39063       52098       60684    15496374      871119
# 4       11372       39892       53374       62302    15820627      911290
#
#   Unnamed: 20
# 0         NaN
# 1         NaN
# 2           계
# 3    16428177
# 4    16794219
#
# [5 rows x 21 columns]
#   Sheet name: 20.신규 등록현황(당월)
#   Unnamed: 0 Unnamed: 1 Unnamed: 2     <   신규   등록현황 (당월계) Unnamed: 7    >  \
# 0      조회년월:    2023.10        NaN   NaN  NaN    NaN   NaN        NaN  NaN
# 1        NaN        차종별         승용   NaN  NaN    NaN    승합        NaN  NaN
# 2        시도별        NaN        신조차   수입차  부활차      계   신조차        수입차  부활차
# 3         서울        NaN       9695  3922   48  13665   191         15    0
# 4         부산        NaN       5354  3191    7   8552    95          2    2
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN          특수         NaN         NaN
# 2          계  ...         부활차           계         신조차         수입차         부활차
# 3        206  ...           0        1324          56          11           0
# 4         99  ...           0         722          20          28           0
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN          합계         NaN         NaN         NaN
# 2           계         신조차         수입차         부활차           계
# 3          67       11187        4027          48       15262
# 4          48        6143        3269           9        9421
#
# [5 rows x 22 columns]
#   Sheet name: 21.신규 등록현황(누계)
#   Unnamed: 0 Unnamed: 1 Unnamed: 2      <   신규    등록현황  (누계) Unnamed: 7    >  \
# 0      조회년월:    2023.10        NaN    NaN  NaN     NaN   NaN        NaN  NaN
# 1        NaN        차종별         승용    NaN  NaN     NaN    승합        NaN  NaN
# 2        시도별        NaN        신조차    수입차  부활차       계   신조차        수입차  부활차
# 3         서울        NaN     106250  36632  567  143449  2117        249   39
# 4         부산        NaN      60958  28882   86   89926  1069         23   60
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN          특수         NaN         NaN
# 2          계  ...         부활차           계         신조차         수입차         부활차
# 3       2405  ...          14       16232         579         142           1
# 4       1152  ...          18        9471         278         342           0
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN          합계         NaN         NaN         NaN
# 2           계         신조차         수입차         부활차           계
# 3         722      124435       37752         621      162808
# 4         620       71329       29676         164      101169
#
# [5 rows x 22 columns]
#   Sheet name: 22.변경 등록현황(당월)
#        <       변경   등록현황 (당월계)           Unnamed: 4 Unnamed: 5      >
# 0  조회년월:  2023.10    NaN   NaN                  NaN        NaN    NaN
# 1    NaN      사유별   주소변경  상호변경             시도를 달리하는         기타      계
# 2    시도별      NaN    NaN   NaN  사용본거지 변경\n(이전등록 포함)        NaN    NaN
# 3     서울      NaN  38142   383                35167       2049  75741
# 4     부산      NaN  19549   167                12812        753  33281
#   Sheet name: 23.변경 등록현황(누계)
#        <       변경    등록현황   (누계)           Unnamed: 4 Unnamed: 5       >
# 0  조회년월:  2023.10     NaN    NaN                  NaN        NaN     NaN
# 1    NaN      사유별    주소변경   상호변경             시도를 달리하는         기타       계
# 2    시도별      NaN     NaN    NaN  사용본거지 변경\n(이전등록 포함)        NaN     NaN
# 3     서울      NaN  374021   6752               370546      23048  774367
# 4     부산      NaN  179699  15975               133515       8263  337452
#   Sheet name: 24.이전 등록현황(당월)
#   Unnamed: 0 Unnamed: 1      <     이전   등록현황 (당월계) Unnamed: 6    > Unnamed: 8
# 0      조회년월:    2023.10    NaN    NaN    NaN   NaN        NaN  NaN        NaN
# 1        NaN        사유별      계   업자매매  당사자매매    증여         상속   촉탁         기타
# 2        시도별        NaN    NaN    NaN    NaN   NaN        NaN  NaN        NaN
# 3         서울        NaN  31539  18723  12058     2        615   73         68
# 4         부산        NaN  16859  11184   5356     0        263   28         28
#   Sheet name: 25.이전 등록현황(누계)
#   Unnamed: 0 Unnamed: 1       <      이전    등록현황 (누계) Unnamed: 6    >  \
# 0      조회년월:    2023.10     NaN     NaN     NaN  NaN        NaN  NaN
# 1        NaN        사유별       계    업자매매   당사자매매   증여         상속   촉탁
# 2        시도별        NaN     NaN     NaN     NaN  NaN        NaN  NaN
# 3         서울        NaN  339057  200185  131358   30       6180  714
# 4         부산        NaN  171022  109054   58622    9       2598  345
#
#   Unnamed: 8
# 0        NaN
# 1         기타
# 2        NaN
# 3        590
# 4        394
#   Sheet name: 26.말소 등록현황(당월)
#   Unnamed: 0 Unnamed: 1  Unnamed: 2                <   말소 등록현황 (당월계)  \
# 0      조회년월:    2023.10         NaN              NaN  NaN  NaN   NaN
# 1        NaN        차종별  자  진  말  소              NaN  NaN  NaN   NaN
# 2        시도별        NaN          폐차  행정처분_x000D_\n이행   도난  대폐차    기타
# 3         서울         승용        4894              NaN    1   58    22
# 4        NaN         승합         324              NaN  NaN    5     1
#
#   Unnamed: 7     > Unnamed: 9  ...          Unnamed: 32 Unnamed: 33  \
# 0        NaN   NaN        NaN  ...                  NaN         NaN
# 1        NaN   NaN        NaN  ...                  NaN         NaN
# 2      양수인불명  차령초과         멸실  ...  등록사항_x000D_\n이 아닌경우     신청이 미출석
# 3        NaN   NaN         92  ...                  NaN         NaN
# 4        NaN   NaN         19  ...                  NaN         NaN
#
#   Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      서식 부적합     등록원부 상이     제시요구 불응          미납    등록요건 미충족       검사 미필
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 40 Unnamed: 41
# 0         NaN         NaN
# 1         NaN         NaN
# 2        운행정지           계
# 3          22          52
# 4         NaN         NaN
#
# [5 rows x 42 columns]
#   Sheet name: 27.말소 등록현황(누계)
#   Unnamed: 0 Unnamed: 1  Unnamed: 2                <   말소 등록현황 (누계)  \
# 0      조회년월:    2023.10         NaN              NaN  NaN  NaN  NaN
# 1        NaN        차종별  자  진  말  소              NaN  NaN  NaN  NaN
# 2        시도별        NaN          폐차  행정처분_x000D_\n이행   도난  대폐차   기타
# 3         서울         승용       50911                4    6  819  162
# 4        NaN         승합        3273              NaN  NaN   57    3
#
#   Unnamed: 7     > Unnamed: 9  ...          Unnamed: 32 Unnamed: 33  \
# 0        NaN   NaN        NaN  ...                  NaN         NaN
# 1        NaN   NaN        NaN  ...                  NaN         NaN
# 2      양수인불명  차령초과         멸실  ...  등록사항_x000D_\n이 아닌경우     신청이 미출석
# 3        NaN     1        779  ...                  NaN         NaN
# 4        NaN   NaN        142  ...                  NaN         NaN
#
#   Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      서식 부적합     등록원부 상이     제시요구 불응          미납    등록요건 미충족       검사 미필
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 40 Unnamed: 41
# 0         NaN         NaN
# 1         NaN         NaN
# 2        운행정지           계
# 3         126         659
# 4           4          54
#
# [5 rows x 42 columns]
# File: 2023년_11월_자동차_등록자료_통계.xlsx
#   Sheet name: 01.통계표
#   Unnamed: 0 Unnamed: 1 Unnamed: 2        <     자동차      통계표 Unnamed: 6  \
# 0      조회년월:    2023.11        NaN      NaN     NaN      NaN        NaN
# 1         차종         차종         승용      NaN     NaN      NaN         승합
# 2        용도별        NaN         관용      자가용     영업용        계         관용
# 3        시도별        NaN        NaN      NaN     NaN      NaN        NaN
# 4         서울        NaN       4580  2651052  120070  2775702       3738
#
#        > Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0    NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1    NaN        NaN        NaN  ...         NaN         NaN          특수
# 2    자가용        영업용          계  ...         영업용           계          관용
# 3    NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4  72616      14920      91274  ...       60306      313246         418
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN          총계         NaN         NaN
# 2         자가용         영업용           계          관용         자가용         영업용
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4        5700        5208       11326       12701     2978343      200504
#
#   Unnamed: 21
# 0         NaN
# 1         NaN
# 2           계
# 3         NaN
# 4     3191548
#
# [5 rows x 22 columns]
#   Sheet name: 02.통계표_시군구
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3      <     자동차      통계표  \
# 0      조회년월:    2023.11        NaN        NaN    NaN     NaN      NaN
# 1         시도        시군구   승      용        NaN    NaN     NaN  승     합
# 2        NaN        NaN         관용        자가용    영업용       계       관용
# 3         서울        강남구        161     212390  18512  231063       57
# 4        NaN        강동구        112     129135   5067  134314       41
#
#   Unnamed: 7    > Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0        NaN  NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN  NaN        NaN  ...         NaN         NaN     특     수
# 2        자가용  영업용          계  ...         영업용           계          관용
# 3       4026  546       4629  ...        2375       16211          20
# 4       3376  799       4216  ...        2544       14857           6
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN     총     계         NaN         NaN
# 2         자가용         영업용           계          관용         자가용         영업용
# 3         349         163         532         419      230420       21596
# 4         209         221         436         313      144879        8631
#
#   Unnamed: 21
# 0         NaN
# 1         NaN
# 2           계
# 3      252435
# 4      153823
#
# [5 rows x 22 columns]
#   Sheet name: 03.수입차_시군구
#   Unnamed: 0 Unnamed: 1       <  시군구  수입차    > Unnamed: 6
# 0      조회년월:    2023.11     NaN  NaN  NaN  NaN        NaN
# 1         시도        시군구      승용   승합   화물   특수         합계
# 2        NaN        NaN     NaN  NaN  NaN  NaN        NaN
# 3         서울        강남구  100274  277  485  123     101159
# 4        NaN        강동구   26288   89  266   50      26693
#   Sheet name: 04.성별_연령별
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       <     자동차      성별     연령별  자동차.1  \
# 0      조회년월:    2023.11        NaN     NaN     NaN     NaN     NaN    NaN
# 1         성별      연령/시도         총계      서울      부산      대구      인천     광주
# 2         남성      10대이하       9741    2297     568     219     482    157
# 3        NaN        20대     540608   53198   26744   24474   32711  19137
# 4        NaN        30대    2330287  317476  125779  110149  145893  67538
#
#      통계표      > Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0    NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 1     대전     울산          세종          경기          강원          충북          충남
# 2    287    210          82        2627         242         377         344
# 3  18651  13947        3540      150340       21415       24882       31369
# 4  71418  56629       24942      694442       68927       84808      119063
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0         NaN         NaN         NaN         NaN         NaN
# 1          전북          전남          경북          경남          제주
# 2         359         328         279         664         219
# 3       21315       23658       31773       36066        7388
# 4       70947       75541      116964      150124       29647
#   Sheet name: 05.차종별_등록현황(전체)
#   < 자동차 등록현황(총 계) > Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     조회년월: 2023.11        NaN        NaN        NaN        NaN        NaN
# 1               NaN        NaN        NaN        NaN      차 종 별         서울
# 2                총계        NaN        NaN        NaN        NaN    3191548
# 3               NaN      승용차합계        NaN        NaN        NaN    2775702
# 4               NaN        NaN    승용일반형 계        NaN        NaN    1838476
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         부산         대구         인천         광주  ...          경기          강원
# 2    1525681    1256740    1726631     722676  ...     6515595      865983
# 3    1290007    1062338    1475439     607852  ...     5444186      668521
# 4     835088     717449     917081     398549  ...     3438990      410109
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          충북          충남          전북          전남          경북          경남
# 2      935402     1243426      991753     1247123     1533003     1941427
# 3      735629      962926      762418      944627     1154629     1583083
# 4      467340      610180      483059      575763      763920     1032522
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1          제주          합계
# 2      702614    25917976
# 3      593670    21358871
# 4      340416    13674275
#
# [5 rows x 23 columns]
#   Sheet name: 06.차종별_등록현황(관용)
#   < 자동차 등록현황(관 용) > Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     조회년월: 2023.11        NaN        NaN        NaN        NaN        NaN
# 1               NaN        NaN        NaN        NaN      차 종 별         서울
# 2                총계        NaN        NaN        NaN        NaN      12701
# 3               NaN      승용차합계        NaN        NaN        NaN       4580
# 4               NaN        NaN    승용일반형 계        NaN        NaN       3172
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         부산         대구         인천         광주  ...          경기          강원
# 2       4793       3679       4318       2420  ...       18591        6608
# 3       1743       1043       1639        878  ...        7900        1953
# 4       1185        689       1162        577  ...        4996        1054
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          충북          충남          전북          전남          경북          경남
# 2        4340        6131        5717        6987        7903        7514
# 3        1403        2018        1895        2330        2689        2557
# 4         886        1230        1111        1376        1544        1478
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1          제주          합계
# 2        2453       99210
# 3         841       35220
# 4         623       22176
#
# [5 rows x 23 columns]
#   Sheet name: 07.차종별_등록현황(자가용)
#   < 자동차 등록현황(자 가 용) > Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       조회년월: 2023.11        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN      차 종 별         서울
# 2                  총계        NaN        NaN        NaN        NaN    2978343
# 3                 NaN      승용차합계        NaN        NaN        NaN    2651052
# 4                 NaN        NaN    승용일반형 계        NaN        NaN    1750100
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         부산         대구         인천         광주  ...          경기          강원
# 2    1347059    1197343    1446054     687539  ...     6238109      832802
# 3    1165687    1032296    1245086     593082  ...     5356310      654084
# 4     774268     695567     780946     386696  ...     3375997      400174
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          충북          충남          전북          전남          경북          경남
# 2      890729     1195735      949603     1009144     1476077     1781101
# 3      716527      947366      746752      745730     1138496     1467927
# 4      454357      598734      471947      466787      751463      975929
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1          제주          합계
# 2      420712    23898652
# 3      324780    20049743
# 4      200274    12906163
#
# [5 rows x 23 columns]
#   Sheet name: 08.차종별 등록현황(영업용)
#   < 자동차 등록현황(영 업 용) > Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       조회년월: 2023.11        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN      차 종 별         서울
# 2                  총계        NaN        NaN        NaN        NaN     200504
# 3                 NaN      승용차합계        NaN        NaN        NaN     120070
# 4                 NaN        NaN    승용일반형 계        NaN        NaN      85204
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13 Unnamed: 14  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1         부산         대구         인천         광주  ...          경기          강원
# 2     173829      55718     276259      32717  ...      258895       26573
# 3     122577      28999     228714      13892  ...       79976       12484
# 4      59635      21193     134973      11276  ...       57997        8881
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          충북          충남          전북          전남          경북          경남
# 2       40333       41560       36433      230992       49023      152812
# 3       17699       13542       13771      196567       13444      112599
# 4       12097       10216       10001      107600       10913       55115
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1          제주          합계
# 2      279449     1920114
# 3      268049     1273908
# 4      139519      745936
#
# [5 rows x 23 columns]
#   Sheet name: 09.차종별_유형별 현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       <     차종별     유형별    등록현황 Unnamed: 7  \
# 0      조회년월:    2023.11        NaN     NaN     NaN     NaN     NaN        NaN
# 1        NaN        시도별         서울      부산      대구      인천      광주         대전
# 2         종별        유형별        NaN     NaN     NaN     NaN     NaN        NaN
# 3         승용         일반    1838476  835088  717449  917081  398549     407820
# 4        NaN      승용겸화물      11854    4418    3466   12407    2253       2502
#
#         > Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0     NaN        NaN         NaN         NaN         NaN         NaN
# 1      울산         세종          경기          강원          충북          충남
# 2     NaN        NaN         NaN         NaN         NaN         NaN
# 3  322793     114720     3438990      410109      467340      610180
# 4    1450        486       21248        2861        3079        3728
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          전북          전남          경북          경남          제주           계
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3      483059      575763      763920     1032522      340416    13674275
# 4        2461        8381        3709        5796        7272       97371
#   Sheet name: 10.연료별_등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    <  연료별  차종별  용도별 등록현황 Unnamed: 8    >  \
# 0      조회년월:    2023.11        NaN  NaN  NaN  NaN  NaN  NaN        NaN  NaN
# 1        연료별        시도별        NaN   서울   부산   대구   인천   광주         대전   울산
# 2        NaN         종별        용도별  NaN  NaN  NaN  NaN  NaN        NaN  NaN
# 3        휘발유                   NaN  NaN  NaN  NaN  NaN  NaN        NaN  NaN
# 4        휘발유                   NaN  NaN  NaN  NaN  NaN  NaN        NaN  NaN
#
#    ... Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0  ...         NaN         NaN         NaN         NaN         NaN
# 1  ...          경기          강원          충북          충남          전북
# 2  ...         NaN         NaN         NaN         NaN         NaN
# 3  ...         NaN         NaN         NaN         NaN         NaN
# 4  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0         NaN         NaN         NaN         NaN         NaN
# 1          전남          경북          경남          제주           계
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 21 columns]
#   Sheet name: 11.최대적재량별_등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       < 최대적재량별  화물자동차   등록현황 Unnamed: 7  \
# 0      조회년월:    2023.11        NaN     NaN    NaN    NaN    NaN        NaN
# 1          규        NaN          모   1톤 이하  1톤 초과  3톤 이상  5톤 이상      8톤 이상
# 2         시도       유  형       용  도     NaN  3톤 미만  5톤 미만  8톤 미만     10톤 미만
# 3         서울        일반형       비사업용  143264  11758   5221   2039        348
# 4        NaN        NaN        사업용   19167   3519   6467   2396       1178
#
#         > Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0     NaN        NaN         NaN         NaN         NaN
# 1  10톤 이상     12톤 이상      15톤 이상      20톤 이상           계
# 2  12톤 미만     15톤 미만      20톤 미만         NaN         NaN
# 3     289        156         191         164      163430
# 4     381        907         235        1368       35618
#   Sheet name: 12.배기별(승용차)_등록현황
#   Unnamed: 0        <     승용차의     배기량별     등록현황 Unnamed: 5        >  \
# 0      조회년월:  2023.11      NaN      NaN      NaN        NaN      NaN
# 1        NaN      배기량  1000 미만  1000 이상  1600 이상    2000 이상  2500 이상
# 2         시도      NaN      NaN  1600 미만  2000 미만    2500 미만      NaN
# 3         서울      NaN   179238   562900  1013328     449362   507607
# 4         부산      NaN   104605   274141   456901     208798   216777
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN
# 1      저속전기차        전기차          계
# 2        NaN        NaN        NaN
# 3         45      63222    2775702
# 4         18      28767    1290007
#   Sheet name: 13.차종별_등록(시도)
#   Unnamed: 0        <      차종별    용도별    등록현황 Unnamed: 5        >
# 0      조회년월:  2023.11      NaN    NaN     NaN        NaN      NaN
# 1        NaN      차종별       승용     승합      화물         특수        계
# 2         시도       용도      NaN    NaN     NaN        NaN      NaN
# 3         서울      사업용   120070  14920   60306       5208   200504
# 4        NaN     비사업용  2655632  76354  252940       6118  2991044
#   Sheet name: 14.차종별_상세등록(시도)
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    <     차령별  차종별    용도별 등록현황  \
# 0        NaN      조회년월:    2023.11        NaN  NaN     NaN  NaN    NaN  NaN
# 1         시도         차종        승 용        NaN  NaN     NaN  승 합    NaN  NaN
# 2        NaN       모델연도         관용        자가용  영업용       계   관용    자가용  영업용
# 3         서울       2003         34     122924  117  123075    7  13039  114
# 4        NaN       2004         12      20603    3   20618    0    417    1
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         특 수         NaN         NaN
# 2          계  ...         영업용           계          관용         자가용         영업용
# 3      13160  ...        1782       39432           0         427         100
# 4        418  ...         466        2769           2          23          22
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         합 계         NaN         NaN         NaN
# 2           계          관용         자가용         영업용           계
# 3         527          51      174030        2113      176194
# 4          47          39       23321         492       23852
#
# [5 rows x 22 columns]
#   Sheet name: 15.차령별_차종별_용도별 등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    <     차령별  차종별    용도별 등록현황   (총계)    >  \
# 0      조회년월:    2023.11        NaN  NaN     NaN  NaN    NaN  NaN    NaN  NaN
# 1         차종        승 용        NaN  NaN     NaN  승 합    NaN  NaN    NaN  화 물
# 2       모델년도         관용        자가용  영업용       계   관용    자가용  영업용      계   관용
# 3       2003         93     624944  427  625464   14  70332  532  70878   88
# 4       2004         27     111859   11  111897    3   3361   20   3384   64
#
#    ... Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0  ...         NaN         NaN         NaN         NaN         NaN
# ...
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 21 columns]
#   Sheet name: 11.최대적재량별_등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       < 최대적재량별  화물자동차   등록현황 Unnamed: 7  \
# 0      조회년월:    2024.10        NaN     NaN    NaN    NaN    NaN        NaN
# 1          규        NaN          모   1톤 이하  1톤 초과  3톤 이상  5톤 이상      8톤 이상
# 2         시도       유  형       용  도     NaN  3톤 미만  5톤 미만  8톤 미만     10톤 미만
# 3         서울        일반형       비사업용  139524  11240   5214   1993        346
# 4        NaN        NaN        사업용   18638   3334   6477   2386       1360
#
#         > Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0     NaN        NaN         NaN         NaN         NaN
# 1  10톤 이상     12톤 이상      15톤 이상      20톤 이상           계
# 2  12톤 미만     15톤 미만      20톤 미만         NaN         NaN
# 3     287        142         190         167      159103
# 4     364        901         236        1320       35016
#   Sheet name: 12.배기별(승용차)_등록현황
#   Unnamed: 0        <     승용차의     배기량별     등록현황 Unnamed: 5        >  \
# 0      조회년월:  2024.10      NaN      NaN      NaN        NaN      NaN
# 1        NaN      배기량  1000 미만  1000 이상  1600 이상    2000 이상  2500 이상
# 2         시도      NaN      NaN  1600 미만  2000 미만    2500 미만      NaN
# 3         서울      NaN   176040   585160   978867     457015   504477
# 4         부산      NaN   105290   296506   446861     213882   221225
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN
# 1      저속전기차        전기차          계
# 2        NaN        NaN        NaN
# 3         55      72027    2773641
# 4         15      36943    1320722
#   Sheet name: 13.차종별_등록(시도)
#   Unnamed: 0        <      차종별    용도별    등록현황 Unnamed: 5        >
# 0      조회년월:  2024.10      NaN    NaN     NaN        NaN      NaN
# 1        NaN      차종별       승용     승합      화물         특수        계
# 2         시도       용도      NaN    NaN     NaN        NaN      NaN
# 3         서울      사업용   114320  14699   59836       5207   194062
# 4        NaN     비사업용  2659321  71606  246517       6358  2983802
#   Sheet name: 14.차종별_상세등록(시도)
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    <     차령별  차종별    용도별 등록현황  \
# 0        NaN      조회년월:    2024.10        NaN  NaN     NaN  NaN    NaN  NaN
# 1         시도         차종        승 용        NaN  NaN     NaN  승 합    NaN  NaN
# 2        NaN       모델연도         관용        자가용  영업용       계   관용    자가용  영업용
# 3         서울       2004         41     126426  120  126587    6  12624  115
# 4        NaN       2005          6      25622    2   25630    2    542   11
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         특 수         NaN         NaN
# 2          계  ...         영업용           계          관용         자가용         영업용
# 3      12745  ...        1841       39547           1         442         111
# 4        555  ...         443        2597           1          25          13
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         합 계         NaN         NaN         NaN
# 2           계          관용         자가용         영업용           계
# 3         554          75      177171        2187      179433
# 4          39          36       28316         469       28821
#
# [5 rows x 22 columns]
#   Sheet name: 15.차령별_차종별_용도별 등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2    <     차령별  차종별    용도별 등록현황   (총계)    >  \
# 0      조회년월:    2024.10        NaN  NaN     NaN  NaN    NaN  NaN    NaN  NaN
# 1         차종        승 용        NaN  NaN     NaN  승 합    NaN  NaN    NaN  화 물
# 2       모델년도         관용        자가용  영업용       계   관용    자가용  영업용      계   관용
# 3       2004        105     640729  437  641271   15  68932  546  69493  108
# 4       2005         32     148222   12  148266    5   4079   32   4116   70
#
#    ... Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0  ...         NaN         NaN         NaN         NaN         NaN
# 1  ...         NaN         NaN         특 수         NaN         NaN
# 2  ...         영업용           계          관용         자가용         영업용
# 3  ...       28024      374963           9        4486        2948
# 4  ...        5278       45152           4         421         437
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         합 계         NaN         NaN         NaN
# 2           계          관용         자가용         영업용           계
# 3        7443         237     1060978       31955     1093170
# 4         862         111      192526        5759      198396
#
# [5 rows x 21 columns]
#   Sheet name: 16.승차정원별(승합차) 등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2     <  승합차의   승차정원별    등록현황 Unnamed: 7  \
# 0      조회년월:    2024.10        NaN   NaN   NaN     NaN     NaN        NaN
# 1          규          모       0-3명  4-6명  7-9명  10-12명  13-15명     16-25명
# 2         시도         용도        NaN   NaN   NaN     NaN     NaN        NaN
# 3         서울        사업용        174    47    58    1934     572       1977
# 4        NaN       비사업용       2252  6252  7807   45757    4894       1628
#
#         > Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0     NaN        NaN         NaN         NaN         NaN
# 1  26-35명     36-45명      46-50명      50명 이상           계
# 2     NaN        NaN         NaN         NaN         NaN
# 3    1074        847        5595        2421       14699
# 4    1112        734        1108          62       71606
#   Sheet name: 17.차종별_규모별 등록현황_초소형
#   Unnamed: 0        <      차종별    규모별    등록현황 Unnamed: 5        >
# 0      조회년월:  2024.10      NaN    NaN     NaN        NaN      NaN
# 1        NaN      차종별       승용     승합      화물         특수        계
# 2         시도       규모      NaN    NaN     NaN        NaN      NaN
# 3         서울       소형    36577   4386  234892       7532   283387
# 4        NaN       중형  1599591  63749   37121       1964  1702425
#   Sheet name: 18.자가용 자동차 증가추세
#   Unnamed: 0        <    자가용     자동차      증가추세         > Unnamed: 6  \
# 0      조회년월:  2024.10    NaN     NaN       NaN       NaN        NaN
# 1         구분      NaN  총보유대수  자가용총대수  자가용승용차전국  자가용승용차서울      자가용승합
# 2         년도        계    NaN     NaN       NaN       NaN        NaN
# 3        NaN   증가율(%)    NaN     NaN       NaN       NaN        NaN
# 4        NaN   구성비(%)    NaN     NaN       NaN       NaN        NaN
#
#   Unnamed: 7 Unnamed: 8
# 0        NaN        NaN
# 1      자가용화물      자가용특수
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
#   Sheet name: 19.연도별 자동차 등록현황
#   Unnamed: 0 Unnamed: 1 Unnamed: 2       <       년도별    자동차    등록현황  \
# 0      조회년월:    2024.10        NaN     NaN       NaN    NaN     NaN
# 1         차종         승용        NaN     NaN       NaN     승합     NaN
# 2         년도         관용        자가용     영업용         계     관용     자가용
# 3       2007      20714   11674085  404980  12099779  12650  999807
# 4       2008      21388   12025715  436706  12483809  13269  987448
#
#   Unnamed: 7        > Unnamed: 9  ... Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0        NaN      NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN      NaN         화물  ...         NaN         NaN          특수
# 2        영업용        계         관용  ...         영업용           계          관용
# 3      92492  1104949      25230  ...      334584     3171351        2090
# 4      95981  1096698      25535  ...      338711     3160338        2110
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN          합계         NaN         NaN
# 2         자가용         영업용           계          관용         자가용         영업용
# 3       10945       39063       52098       60684    15496374      871119
# 4       11372       39892       53374       62302    15820627      911290
#
#   Unnamed: 20
# 0         NaN
# 1         NaN
# 2           계
# 3    16428177
# 4    16794219
#
# [5 rows x 21 columns]
#   Sheet name: 20.신규 등록현황(당월)
#   Unnamed: 0 Unnamed: 1 Unnamed: 2     <   신규   등록현황 (당월계) Unnamed: 7    >  \
# 0      조회년월:    2024.10        NaN   NaN  NaN    NaN   NaN        NaN  NaN
# 1        NaN        차종별         승용   NaN  NaN    NaN    승합        NaN  NaN
# 2        시도별        NaN        신조차   수입차  부활차      계   신조차        수입차  부활차
# 3         서울        NaN       9616  3716   53  13385   252         20    1
# 4         부산        NaN       7040  3374    5  10419   145         14    3
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN          특수         NaN         NaN
# 2          계  ...         부활차           계         신조차         수입차         부활차
# 3        273  ...           2        1202          34          10           0
# 4        162  ...           0         693          26          30           0
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN          합계         NaN         NaN         NaN
# 2           계         신조차         수입차         부활차           계
# 3          44       11016        3832          56       14904
# 4          56        7857        3465           8       11330
#
# [5 rows x 22 columns]
#   Sheet name: 21.신규 등록현황(누계)
#   Unnamed: 0 Unnamed: 1 Unnamed: 2      <   신규    등록현황  (누계) Unnamed: 7    >  \
# 0      조회년월:    2024.10        NaN    NaN  NaN     NaN   NaN        NaN  NaN
# 1        NaN        차종별         승용    NaN  NaN     NaN    승합        NaN  NaN
# 2        시도별        NaN        신조차    수입차  부활차       계   신조차        수입차  부활차
# 3         서울        NaN      93164  37242  635  131041  2207        293   28
# 4         부산        NaN      63466  32340   95   95901   998         28   24
#
#   Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN          특수         NaN         NaN
# 2          계  ...         부활차           계         신조차         수입차         부활차
# 3       2528  ...          23       13079         462          76           0
# 4       1050  ...           2        7009         246         286           0
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN          합계         NaN         NaN         NaN
# 2           계         신조차         수입차         부활차           계
# 3         538      108326       38174         686      147186
# 4         532       71317       33054         121      104492
#
# [5 rows x 22 columns]
#   Sheet name: 22.변경 등록현황(당월)
#        <       변경   등록현황 (당월계)           Unnamed: 4 Unnamed: 5      >
# 0  조회년월:  2024.10    NaN   NaN                  NaN        NaN    NaN
# 1    NaN      사유별   주소변경  상호변경             시도를 달리하는         기타      계
# 2    시도별      NaN    NaN   NaN  사용본거지 변경\n(이전등록 포함)        NaN    NaN
# 3     서울      NaN  39388   358                39417       2143  81306
# 4     부산      NaN  21301   173                14636        808  36918
#   Sheet name: 23.변경 등록현황(누계)
#        <       변경    등록현황  (누계)           Unnamed: 4 Unnamed: 5       >
# 0  조회년월:  2024.10     NaN   NaN                  NaN        NaN     NaN
# 1    NaN      사유별    주소변경  상호변경             시도를 달리하는         기타       계
# 2    시도별      NaN     NaN   NaN  사용본거지 변경\n(이전등록 포함)        NaN     NaN
# 3     서울      NaN  367505  5389               368709      22945  764548
# 4     부산      NaN  166100  3438               142428       8197  320163
#   Sheet name: 24.이전 등록현황(당월)
#   Unnamed: 0 Unnamed: 1      <     이전   등록현황 (당월계) Unnamed: 6    > Unnamed: 8
# 0      조회년월:    2024.10    NaN    NaN    NaN   NaN        NaN  NaN        NaN
# 1        NaN        사유별      계   업자매매  당사자매매    증여         상속   촉탁         기타
# 2        시도별        NaN    NaN    NaN    NaN   NaN        NaN  NaN        NaN
# 3         서울        NaN  33521  20354  12380     4        599   67        117
# 4         부산        NaN  18618  12477   5796     2        256   31         56
#   Sheet name: 25.이전 등록현황(누계)
#   Unnamed: 0 Unnamed: 1       <      이전    등록현황 (누계) Unnamed: 6    >  \
# 0      조회년월:    2024.10     NaN     NaN     NaN  NaN        NaN  NaN
# 1        NaN        사유별       계    업자매매   당사자매매   증여         상속   촉탁
# 2        시도별        NaN     NaN     NaN     NaN  NaN        NaN  NaN
# 3         서울        NaN  332046  199416  125014   54       6113  662
# 4         부산        NaN  177590  117719   56553   40       2609  358
#
#   Unnamed: 8
# 0        NaN
# 1         기타
# 2        NaN
# 3        787
# 4        311
#   Sheet name: 26.말소 등록현황(당월)
#   Unnamed: 0 Unnamed: 1  Unnamed: 2                <   말소 등록현황 (당월계)  \
# 0      조회년월:    2024.10         NaN              NaN  NaN  NaN   NaN
# 1        NaN        차종별  자  진  말  소              NaN  NaN  NaN   NaN
# 2        시도별        NaN          폐차  행정처분_x000D_\n이행   도난  대폐차    기타
# 3         서울         승용        5456                1  NaN   78    12
# 4        NaN         승합         427              NaN  NaN    4     1
#
#   Unnamed: 7     > Unnamed: 9  ... Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0        NaN   NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN   NaN        NaN  ...         NaN         NaN         NaN
# 2      양수인불명  차령초과         멸실  ...     신청이 미출석      서식 부적합     등록원부 상이
# 3        NaN   NaN        119  ...         NaN         NaN         NaN
# 4        NaN   NaN         11  ...         NaN         NaN         NaN
#
#   Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2     제시요구 불응          미납    등록요건 미충족       검사 미필        운행정지     의무보험미가입
# 3         NaN         NaN         NaN         NaN          10           1
# 4         NaN         NaN         NaN         NaN           1         NaN
#
#   Unnamed: 42
# 0         NaN
# 1         NaN
# 2           계
# 3          43
# 4           8
#
# [5 rows x 43 columns]
#   Sheet name: 27.말소 등록현황(누계)
#   Unnamed: 0 Unnamed: 1  Unnamed: 2                <   말소 등록현황 (누계)  \
# 0      조회년월:    2024.10         NaN              NaN  NaN  NaN  NaN
# 1        NaN        차종별  자  진  말  소              NaN  NaN  NaN  NaN
# 2        시도별        NaN          폐차  행정처분_x000D_\n이행   도난  대폐차   기타
# 3         서울         승용       49226                4   11  877   99
# 4        NaN         승합        2838              NaN    2   48    2
#
#   Unnamed: 7     > Unnamed: 9  ... Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0        NaN   NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN   NaN        NaN  ...         NaN         NaN         NaN
# 2      양수인불명  차령초과         멸실  ...     신청이 미출석      서식 부적합     등록원부 상이
# 3        NaN     1        877  ...         NaN         NaN         NaN
# 4        NaN     1        141  ...         NaN         NaN         NaN
#
#   Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2     제시요구 불응          미납    등록요건 미충족       검사 미필        운행정지     의무보험미가입
# 3         NaN         NaN           4         NaN         119           7
# 4         NaN         NaN         NaN         NaN           3         NaN
#
#   Unnamed: 42
# 0         NaN
# 1         NaN
# 2           계
# 3         546
# 4          36
#
# [5 rows x 43 columns]

# %%
# 뭐뭐들었나 확인해봄
excel_files
# Out:
# ['2023년_10월_자동차_등록자료_통계.xlsx',
#  '2023년_11월_자동차_등록자료_통계.xlsx',
#  '2023년_12월_자동차_등록자료_통계.xlsx',
#  '2024년_01월_자동차_등록자료_통계.xlsx',
#  '2024년_02월_자동차_등록자료_통계.xlsx',
#  '2024년_03월_자동차_등록자료_통계.xlsx',
#  '2024년_04월_자동차_등록자료_통계.xlsx',
#  '2024년_05월_자동차_등록자료_통계.xlsx',
#  '2024년_06월_자동차_등록자료_통계.xlsx',
#  '2024년_07월_자동차_등록자료_통계.xlsx',
#  '2024년_08월_자동차_등록자료_통계.xlsx',
#  '2024년_09월_자동차_등록자료_통계.xlsx',
#  '2024년_10월_자동차_등록자료_통계.xlsx']

# %%
# 시트이름 조회
list(all_data[excel_files[0]])
# Out:
# ['01.통계표',
#  '02.통계표_시군구',
#  '03.수입차_시군구',
#  '04.성별_연령별',
#  '05.차종별_등록현황(전체)',
#  '06.차종별_등록현황(관용)',
#  '07.차종별_등록현황(자가용)',
#  '08.차종별 등록현황(영업용)',
#  '09.차종별_유형별 현황',
#  '10.연료별_등록현황',
#  '11.최대적재량별_등록현황',
#  '12.배기별(승용차)_등록현황',
#  '13.차종별_등록(시도)',
#  '14.차종별_상세등록(시도)',
#  '15.차령별_차종별_용도별 등록현황',
#  '16.승차정원별(승합차) 등록현황',
#  '17.차종별_규모별 등록현황_초소형',
#  '18.자가용 자동차 증가추세',
#  '19.연도별 자동차 등록현황',
#  '20.신규 등록현황(당월)',
#  '21.신규 등록현황(누계)',
#  '22.변경 등록현황(당월)',
#  '23.변경 등록현황(누계)',
#  '24.이전 등록현황(당월)',
#  '25.이전 등록현황(누계)',
#  '26.말소 등록현황(당월)',
#  '27.말소 등록현황(누계)']

# %%
all_df = pd.DataFrame()
for file, sheets in all_data.items():
    # 특정 시트 이름을 선택해서 변환
    year = file[:4]
    month = file[6:8]
    if '04.성별_연령별' in sheets:
        df = sheets['04.성별_연령별']
        df.columns = df.iloc[1]  # 세 번째 줄을 컬럼으로 설정
        df = df.drop([0, 1]).reset_index(drop=True)  # 첫 세 줄 제거 후 인덱스 재설정
        df.rename(columns={('연령/시도'): ('연령')}, inplace=True) # 연령/시도 -> 연령으로 컬럼 변경 
        df.drop(columns=['총계'], inplace=True) # 총계 컬럼 삭제
        # 성별 컬럼에 남성/여성으로 채움 
        df[("성별")] = df[("성별")].fillna(method='ffill')
        # 합계, 사업자 행 삭제 
        df = df[~df['연령'].isin(['계', '법인 및 사업자']) & df['연령'].notna()]
        # 성별, 연령외의 컬럼을 값으로 변경 
        df2 = df.melt(id_vars=[('성별'), ('연령')])
        # 컬럼명 변경
        df2.columns = ['gender', 'age', 'district_si', 'num']
        # 년, 월 
        df2['year'] = year
        df2['month'] = month
        # 컬럼순서 조절 
        df2 = df2[['year', 'month', 'gender', 'age', 'district_si', 'num']]
        # 결과를 all_df에 누적
        all_df = pd.concat([all_df, df2], ignore_index=True)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_8252\1099593437.py:13: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[("성별")] = df[("성별")].fillna(method='ffill')

# %%
# 고유한 PK로 사용할 'index' 컬럼 생성
all_df.reset_index(drop=True, inplace=True)  # 인덱스 초기화
all_df['id'] = all_df.index + 1  # 'pk' 컬럼 생성 (1부터 시작하는 고유 인덱스)

# 컬럼 순서에 'pk' 추가
all_df = all_df[['id', 'year', 'month', 'gender', 'age', 'district_si', 'num']]
# Out:
#         id  year  month gender    age district_si     num
# 0        1  2023     10     남성  10대이하          서울    2306
# 1        2  2023     10     남성    20대          서울   53299
# 2        3  2023     10     남성    30대          서울  318679
# 3        4  2023     10     남성    40대          서울  503280
# 4        5  2023     10     남성    50대          서울  531615
# ...    ...   ...    ...    ...    ...         ...     ...
# 3973  3974  2024     10     여성    50대          제주   34488
# 3974  3975  2024     10     여성    60대          제주   22463
# 3975  3976  2024     10     여성    70대          제주    5058
# 3976  3977  2024     10     여성    80대          제주     753
# 3977  3978  2024     10     여성  90대이상          제주     128
#
# [3978 rows x 7 columns]

# %%
# pip install sqlalchemy
# !pip install mysqlclient 
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1

# %% [markdown]
# # db에 넣기

# %%
# db 연결정보 
# 이부분 지움

# %%
import pymysql
# 이부분 지움
cursor = con.cursor()
# Out:
# 0

# %%
# 테이블 생성
create_table_sql = """CREATE TABLE gender_age (
            id int NOT NULL,
            year char(50) NULL,
            month char(50) NULL,
            gender char(10) NULL,
            age VARCHAR(15) NULL,
            district_si VARCHAR(20) NULL,
            num int NULL
        );"""

cursor.execute(create_table_sql)

# PRIMARY KEY 추가
alter_table_sql = "ALTER TABLE gender_age ADD PRIMARY KEY (id);"
cursor.execute(alter_table_sql)
# Out:
# 0

# %%
# 테이블에 데이터 넣기 
all_df.to_sql('gender_age', if_exists='append', index=False, con=engine)
# Out:
# 3978

# %%
all_df
# Out:
#         pk  year  month gender    age district_si     num
# 0        1  2023     10     남성  10대이하          서울    2306
# 1        2  2023     10     남성    20대          서울   53299
# 2        3  2023     10     남성    30대          서울  318679
# 3        4  2023     10     남성    40대          서울  503280
# 4        5  2023     10     남성    50대          서울  531615
# ...    ...   ...    ...    ...    ...         ...     ...
# 3973  3974  2024     10     여성    50대          제주   34488
# 3974  3975  2024     10     여성    60대          제주   22463
# 3975  3976  2024     10     여성    70대          제주    5058
# 3976  3977  2024     10     여성    80대          제주     753
# 3977  3978  2024     10     여성  90대이상          제주     128
#
# [3978 rows x 7 columns]
